# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
url = "https://raw.githubusercontent.com/mahesh147/Random-Forest-Classifier/master/Social_Network_Ads.csv"

df = pd.read_csv(url)

# %%
print(df.head())
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df=df.iloc[:,2:]

# %%
df
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %% [markdown]
# TRAIN TEST SPLIT

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(df.drop("Purchased", axis=1),df["Purchased"],test_size=0.3,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
scaler.mean_
# Out:
# array([3.78642857e+01, 6.98071429e+04])

# %%
X_train_scaled=pd.DataFrame(X_train_scaled,columns=X_train.columns)
X_test_scaled=pd.DataFrame(X_test_scaled,columns=X_test.columns)

# %%
X_train_scaled
# Out:
#           Age  EstimatedSalary
# 0   -1.163172        -1.584970
# 1    2.170181         0.930987
# 2    0.013305         1.220177
# 3    0.209385         1.075582
# 4    0.405465        -0.486047
# ..        ...              ...
# 275  0.993704        -1.151185
# 276 -0.869053        -0.775237
# 277 -0.182774        -0.514966
# 278 -1.065133        -0.457127
# 279 -1.163172         1.393691
#
# [280 rows x 2 columns]

# %%
np.round(X_train.describe(),2)
# Out:
#           Age  EstimatedSalary
# count  280.00           280.00
# mean    37.86         69807.14
# std     10.22         34641.20
# min     18.00         15000.00
# 25%     30.00         43000.00
# 50%     37.00         70500.00
# 75%     46.00         88000.00
# max     60.00        150000.00

# %%
np.round(X_train_scaled.describe(),2)
# Out:
#           Age  EstimatedSalary
# count  280.00           280.00
# mean     0.00             0.00
# std      1.00             1.00
# min     -1.95            -1.58
# 25%     -0.77            -0.78
# 50%     -0.08             0.02
# 75%      0.80             0.53
# max      2.17             2.32

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,6))
ax1.scatter(X_train["Age"], X_train["EstimatedSalary"])
ax1.set_title("Before Standardization")
ax2.scatter(X_train_scaled["Age"], X_train_scaled["EstimatedSalary"])
ax2.set_title("After Standardization")
# Out:
# Text(0.5, 1.0, 'After Standardization')

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,6))
ax1.set_title("Before Standardization")
sns.kdeplot(X_train["Age"], ax=ax1)
sns.kdeplot(X_train["EstimatedSalary"], ax=ax1)
ax2.set_title("After Standardization")
sns.kdeplot(X_train_scaled["Age"], ax=ax2)
sns.kdeplot(X_train_scaled["EstimatedSalary"], ax=ax2)
# Out:
# <Axes: title={'center': 'After Standardization'}, xlabel='Age', ylabel='Density'>

# %% [markdown]
# COMPARISON OF DISTRIBUTION

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,6))
ax1.set_title("Before Standardization")
sns.kdeplot(X_train["Age"], ax=ax1)
ax2.set_title("After Standardization")
sns.kdeplot(X_train_scaled["Age"], ax=ax2)
# Out:
# <Axes: title={'center': 'After Standardization'}, xlabel='Age', ylabel='Density'>

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,6))
ax1.set_title("Before Standardization")
sns.kdeplot(X_train["EstimatedSalary"], ax=ax1)
ax2.set_title("After Standardization")
sns.kdeplot(X_train_scaled["EstimatedSalary"], ax=ax2)
# Out:
# <Axes: title={'center': 'After Standardization'}, xlabel='EstimatedSalary', ylabel='Density'>

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()
lr_scaled=LogisticRegression()
lr.fit(X_train,y_train)
lr_scaled.fit(X_train_scaled,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lr.predict(X_test)
y_pred_scaled=lr_scaled.predict(X_test_scaled)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.875

# %%
accuracy_score(y_test,y_pred_scaled)
# Out:
# 0.8666666666666667

# %% [markdown]
# EFFECT OF OUTLIERS

# %%
df = pd.concat([df, pd.DataFrame({"Age":[5,90,95], "EstimatedSalary":[1000,250000,350000], "Purchased":[0,1,1]})], ignore_index=True)

# %%
plt.scatter(df["Age"], df["EstimatedSalary"])

# %%
X_train,X_test,y_train,y_test = train_test_split(df.drop("Purchased", axis=1),df["Purchased"],test_size=0.3,random_state=0)

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled=pd.DataFrame(X_train_scaled,columns=X_train.columns)
X_test_scaled=pd.DataFrame(X_test_scaled,columns=X_test.columns)

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,6))
ax1.scatter(X_train["Age"], X_train["EstimatedSalary"])
ax1.set_title("Before Standardization")
ax2.scatter(X_train_scaled["Age"], X_train_scaled["EstimatedSalary"])
ax2.set_title("After Standardization")
# Out:
# Text(0.5, 1.0, 'After Standardization')
