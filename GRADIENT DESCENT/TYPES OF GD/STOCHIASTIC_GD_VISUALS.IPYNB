# %%
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression

import numpy as np
import matplotlib.pyplot as plt

from matplotlib.animation import FuncAnimation
import matplotlib.animation as animation
from IPython.display import HTML

# %%
X,y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1,noise=20,random_state=13)
plt.scatter(X,y)

# %%
lr = LinearRegression()
lr.fit(X,y)
print(lr.coef_)
print(lr.intercept_)

# %%
import time

b = 150
m = -127.82
all_b = []
all_m = []
all_cost = []
all_lr = []


epochs = 100

start = time.time()

t0,t1 = 5,50
def learning_rate(t):
    return t0/(t + t1)

for i in range(epochs):
    for j in range(X.shape[0]):
        
        lr = learning_rate(i * X.shape[0] + j)
        
        idx = np.random.randint(X.shape[0], size=1)
        
        slope_b = -2 * (y[idx] - (m * X[idx]) -  b)
        slope_m = -2 * (y[idx] - (m * X[idx]) -  b) * X[idx]
        cost = (y[idx] - m * X[idx] -b) ** 2
        
        
        b = b - (lr * slope_b)
        m = m - (lr * slope_m)
        all_b.append(b)
        all_m.append(m)
        all_cost.append(cost)
        all_lr.append(lr)
print("Total time taken",time.time() - start)

# %%
len(all_cost)

# %%
# %matplotlib widget
fig, ax = plt.subplots(figsize=(9,5))
#fig.set_tight_layout(True)

x_i = np.arange(-3, 3, 0.1)
y_i = x_i*(-27) -150
ax.scatter(X, y)
line, = ax.plot(x_i, x_i*50 - 4, 'r-', linewidth=2)

def update(i):
    label = 'epoch {0}'.format(i + 1)
    line.set_ydata(x_i*all_m[i] + all_b[i])
    ax.set_xlabel(label)
    # return line, ax

anim = FuncAnimation(fig, update, frames=100, interval=5)
plt.show()
#f = r"stochastic_animation_line_plot.gif" 
#writergif = animation.PillowWriter(fps=2) 
#anim.save(f, writer=writergif)

# %%
m_arr = np.linspace(-150, 150, 10)
b_arr = np.linspace(-150, 150, 10)
mGrid, bGrid = np.meshgrid(m_arr,b_arr)

final = np.vstack((mGrid.ravel().reshape(1,100),bGrid.ravel().reshape(1,100))).T

z_arr = []

for i in range(final.shape[0]):
    z_arr.append(np.sum((y - final[i,0]*X.reshape(100) - final[i,1])**2))

z_arr = np.array(z_arr).reshape(10,10)

# %%
# %matplotlib widget
from matplotlib.animation import FuncAnimation
import matplotlib.animation as animation

# intercept graph
num_epochs = list(range(0,30))
fig = plt.figure(figsize=(9,5)) 
axis = plt.axes(xlim =(-150, 150), ylim =(-150, 150)) 

axis.contourf(m_arr, b_arr, z_arr)

line, = axis.plot([], [], lw = 2,color='white') 
  
xdata, ydata = [], [] 
  
# animation function 
def animate(i): 
    label = 'epoch {0}'.format(i + 1)
    xdata.append(all_m[i]) 
    ydata.append(all_b[i]) 
    line.set_data(xdata, ydata) 
    axis.set_xlabel(label)
      
    return line, 
  
# calling the animation function     
anim = animation.FuncAnimation(fig, animate, frames = 100,repeat=False, interval = 100)

#f = r"stochastic_animation_contour_plot.gif" 
#writergif = animation.PillowWriter(fps=2) 
#anim.save(f, writer=writergif)

# %%
all_b[-1]

# %%
all_m[-1]

# %% [markdown]
# num_epochs = list(range(0,100))
# fig = plt.figure(figsize=(9,5))
# axis = plt.axes(xlim =(0, 31), ylim =(0, 175000))
#
# line, = axis.plot([], [], lw = 2)
#
# xdata, ydata = [], []
#
# # animation function
# def animate(i):
#     label = 'epoch {0}'.format(i + 1)
#     xdata.append(num_epochs[i])
#     ydata.append(all_cost[i])
#     line.set_data(xdata, ydata)
#     axis.set_xlabel(label)
#
#     return line,
#
# # calling the animation function
# anim = animation.FuncAnimation(fig, animate, frames = 100,repeat=False, interval = 150)
# plt.show()
# #f = r"stochastic_animation_cost_plot.gif"
# #writergif = animation.PillowWriter(fps=2)
# #anim.save(f, writer=writergif)

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML

num_epochs = list(range(0, 100))
fig = plt.figure(figsize=(9,5)) 

# FIX 1: Expand xlim to 100 so your line doesn't disappear off the screen at epoch 31!
axis = plt.axes(xlim=(0, 100), ylim=(0, 175000)) 
  
line, = axis.plot([], [], lw=2) 
  
xdata, ydata = [], [] 
  
# animation function 
def animate(i): 
    label = 'epoch {0}'.format(i + 1)
    
    # FIX 2: Force the cost value to be a raw float scalar, completely destroying the dimension mismatch
    cost_val = float(np.ravel(all_cost[i])[0])
    
    xdata.append(num_epochs[i]) 
    ydata.append(cost_val) 
    
    line.set_data(xdata, ydata) 
    axis.set_xlabel(label)
      
    return line, 
  
# Safely cap frames at whatever the actual length of your calculated cost history is
total_frames = min(len(all_cost), 100)

# calling the animation function     
anim = animation.FuncAnimation(fig, animate, frames=total_frames, repeat=False, interval=150)
# 2. KILL THE BLANK STATIC GRAPH PREVIEW
plt.close(fig) 

# 3. FORCE JUPYTER TO GENERATE AN INTERACTIVE VIDEO CONTROLLER
HTML(anim.to_jshtml())
# To save this running cost curve, uncomment below:
# f = r"stochastic_animation_cost_plot.gif" 
# writergif = animation.PillowWriter(fps=5) 
# anim.save(f, writer=writergif)

# %%
import numpy as np
import matplotlib.pyplot as plt


fig,ax=plt.subplots(1,1)
plt.figure(figsize=(18,4))
cp = ax.contourf(m_arr, b_arr, z_arr)
ax.plot(np.array(all_m).ravel(),np.array(all_b).ravel(),color='white')
fig.colorbar(cp) # Add a colorbar to a plot
ax.set_title('Filled Contours Plot')
ax.set_xlabel('m')
ax.set_ylabel('b')
plt.show()
all_lr[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       3
#       4
#       5 fig,ax=plt.subplots(1,1)
#       6 plt.figure(figsize=(18,4))
# ----> 7 cp = ax.contourf(m_arr, b_arr, z_arr)
#       8 ax.plot(np.array(all_m).ravel(),np.array(all_b).ravel(),color='white')
#       9 fig.colorbar(cp) # Add a colorbar to a plot
#      10 ax.set_title('Filled Contours Plot')
#
# NameError: name 'm_arr' is not defined

# %%
all_lr[-1]
